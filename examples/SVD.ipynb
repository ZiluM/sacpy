# %%
import sacpy as scp
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from xmca import array
import sacpy.Map
import cartopy.crs as ccrs

# %%
sst = scp.load_sst()['sst'].loc["1991":"2021", -20:30, 150:275]
ssta = scp.get_anom(sst)

# %%
wu = xr.open_dataset("../../DATA/uwnd.10m.gauss.1948-2021.nc1")['uwnd'].\
    loc["1991":"2021"].resample({
    "time":
    "1m"
}).mean().interp(lon=ssta.lon,lat=ssta.lat)
vu = xr.open_dataset("../../DATA/vwnd.10m.gauss.1948-2021.nc1")['vwnd'].\
    loc["1991":"2021"].resample({
    "time":
    "1m"
}).mean().interp(lon=ssta.lon,lat=ssta.lat)

# %%
wua = scp.get_anom(wu)
vua = scp.get_anom(vu)

# %%
wvua = wua + vua * 1j

# %%
svd = scp.SVD(ssta,wvua,complex=True)
svd.solve()

# %%
ptl, ptr = svd.get_pt(3)
pcl,pcr = svd.get_pc(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb Cell 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ptl, ptr = svd.get_pt(3)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> pcl,pcr = svd.get_pc(3)
#
# File /mnt/d/PythonPP20/sacpy/sacpy/SVD.py:77, in SVD.get_pc(self, npt)
#      76 def get_pc(self, npt):
# ---> 77     pc_left = self._U[:, :npt].T @ self.rsp_data1.T
#      78     pc_right = self._V[:npt, :] @ self.rsp_data2.T
#      79     return pc_left, pc_right
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1575 is different from 1521)

# %%
u = np.real(ptr[1])
v = np.imag(ptr[1])
sst_pt = np.real(ptl)

# %%
import cartopy.crs as ccrs
import sacpy.Map
lon , lat = np.array(ssta.lon) , np.array(ssta.lat)
fig = plt.figure(figsize=[15,10])
ax = fig.add_subplot(221,projection=ccrs.PlateCarree(central_longitude=180))
m1 = ax.scontourf(lon,lat,sst_pt[0],cmap='RdBu_r',levels=np.linspace(-0.75,0.75,15),extend="both")
ax.scontour(m1,colors="black")
ax.init_map(smally=2.5)
# plt.colorbar(m1)
ax2 = fig.add_subplot(222)
ax2.plot(sst.time,pc[0])
ax3 = fig.add_subplot(223,projection=ccrs.PlateCarree(central_longitude=180))
m2 = ax3.scontourf(lon,lat,sst_pt[1],cmap='RdBu_r',levels=np.linspace(-0.75,0.75,15),extend="both")
ax3.scontour(m2,colors="black")
ax3.init_map(smally=2.5)
ax4 = fig.add_subplot(224)
ax4.plot(sst.time,pc[1])
cb_ax = fig.add_axes([0.1,0.06,0.4,0.02])
fig.colorbar(m1,cax=cb_ax,orientation="horizontal")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb Cell 9 in <cell line: 8>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> m1 = ax.scontourf(lon,lat,sst_pt[0],cmap='RdBu_r',levels=np.linspace(-0.75,0.75,15),extend="both")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> ax.scontour(m1,colors="black")
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> ax.init_map(ysmall=2.5)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # plt.colorbar(m1)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/zilumeng/PythonPP20/sacpy/examples/SVD.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> ax2 = fig.add_subplot(222)
#
# File /mnt/d/PythonPP20/sacpy/sacpy/Map.py:257, in _initialize_map(self, same_size, coastlines, **kwargs)
#     255     self.set_aspect("auto")
#     256 extend = self._get_extends()
# --> 257 self.draw_ticks(extend, **kwargs)
#
# TypeError: _draw_ticks() got an unexpected keyword argument 'ysmall'
